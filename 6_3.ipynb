# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy import integrate
from mpl_toolkits.mplot3d import Axes3D

from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPool2D, LSTM
from keras import optimizers
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K

# %%
import os
import scipy.io
import scipy.misc
import skimage
from skimage.transform import resize
plt.rcParams['figure.figsize'] = [10, 10]
plt.rcParams.update({'font.size': 18})

mat_contents = scipy.io.loadmat(os.path.join('/Users/zhhh/databook_python/DATA/VORTALL.mat'))
X=mat_contents['VORTALL'].T

# %%
nn_input = X[:100,:]
nn_output = X[1:101,:]

# %% [markdown]
# ## feedforward NN

# %%
model = Sequential()

#add model layers
model.add(Dense(1024, activation='sigmoid'))
model.add(Dense(512, activation='relu'))
model.add(Dense(64, activation='linear'))
model.add(Dense(512, activation='linear'))
model.add(Dense(1024, activation='linear'))
model.add(Dense(89351, activation='linear'))

sgd_optimizer = optimizers.SGD(momentum=0.9)
model.compile(optimizer='adam', loss='mse')
History = model.fit(nn_input, nn_output, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 10s 1s/step - loss: 1.2370
# Epoch 2/100
# 4/4 [==============================] - 4s 854ms/step - loss: 0.6617
# Epoch 3/100
# 4/4 [==============================] - 4s 937ms/step - loss: 0.4616
# Epoch 4/100
# 4/4 [==============================] - 4s 975ms/step - loss: 0.3893
# Epoch 5/100
# 4/4 [==============================] - 4s 906ms/step - loss: 0.3379
# Epoch 6/100
# 4/4 [==============================] - 4s 917ms/step - loss: 0.3037
# Epoch 7/100
# 4/4 [==============================] - 4s 1s/step - loss: 0.2941
# Epoch 8/100
# 4/4 [==============================] - 3s 846ms/step - loss: 0.2902
# Epoch 9/100
# 4/4 [==============================] - 4s 876ms/step - loss: 0.2388
# Epoch 10/100
# 4/4 [==============================] - 3s 846ms/step - loss: 0.1816
# Epoch 11/100
# 4/4 [==============================] - 3s 865ms/step - loss: 0.1561
# Epoch 12/100
# 4/4 [==============================] - 4s 861ms/step - loss: 0.1373
# Epoch 13/100
# 4/4 [==============================] - 3s 863ms/step - loss: 0.1018
# Epoch 14/100
# 4/4 [==============================] - 4s 910ms/step - loss: 0.0904
# Epoch 15/100
# 4/4 [==============================] - 4s 865ms/step - loss: 0.0790
# Epoch 16/100
# 4/4 [==============================] - 3s 831ms/step - loss: 0.0751
# Epoch 17/100
# 4/4 [==============================] - 4s 862ms/step - loss: 0.0732
# Epoch 18/100
# 4/4 [==============================] - 3s 854ms/step - loss: 0.0736
# Epoch 19/100
# 4/4 [==============================] - 4s 880ms/step - loss: 0.0737
# Epoch 20/100
# 4/4 [==============================] - 3s 820ms/step - loss: 0.0703
# Epoch 21/100
# 4/4 [==============================] - 3s 858ms/step - loss: 0.0693
# Epoch 22/100
# 4/4 [==============================] - 4s 998ms/step - loss: 0.0707
# Epoch 23/100
# 4/4 [==============================] - 3s 852ms/step - loss: 0.0726
# Epoch 24/100
# 4/4 [==============================] - 3s 852ms/step - loss: 0.0683
# Epoch 25/100
# 4/4 [==============================] - 3s 830ms/step - loss: 0.0665
# Epoch 26/100
# 4/4 [==============================] - 4s 866ms/step - loss: 0.0630
# Epoch 27/100
# 4/4 [==============================] - 3s 853ms/step - loss: 0.0672
# Epoch 28/100
# 4/4 [==============================] - 3s 832ms/step - loss: 0.0659
# Epoch 29/100
# 4/4 [==============================] - 4s 891ms/step - loss: 0.0615
# Epoch 30/100
# 4/4 [==============================] - 4s 874ms/step - loss: 0.0632
# Epoch 31/100
# 4/4 [==============================] - 4s 892ms/step - loss: 0.0631
# Epoch 32/100
# 4/4 [==============================] - 3s 866ms/step - loss: 0.0617
# Epoch 33/100
# 4/4 [==============================] - 4s 899ms/step - loss: 0.0594
# Epoch 34/100
# 4/4 [==============================] - 3s 852ms/step - loss: 0.0595
# Epoch 35/100
# 4/4 [==============================] - 4s 868ms/step - loss: 0.0575
# Epoch 36/100
# 4/4 [==============================] - 3s 843ms/step - loss: 0.0582
# Epoch 37/100
# 4/4 [==============================] - 4s 867ms/step - loss: 0.0582
# Epoch 38/100
# 4/4 [==============================] - 4s 936ms/step - loss: 0.0590
# Epoch 39/100
# 4/4 [==============================] - 4s 908ms/step - loss: 0.0546
# Epoch 40/100
# 4/4 [==============================] - 4s 883ms/step - loss: 0.0564
# Epoch 41/100
# 4/4 [==============================] - 4s 889ms/step - loss: 0.0513
# Epoch 42/100
# 4/4 [==============================] - 3s 873ms/step - loss: 0.0523
# Epoch 43/100
# 4/4 [==============================] - 4s 939ms/step - loss: 0.0506
# Epoch 44/100
# 4/4 [==============================] - 4s 942ms/step - loss: 0.0508
# Epoch 45/100
# 4/4 [==============================] - 3s 868ms/step - loss: 0.0480
# Epoch 46/100
# 4/4 [==============================] - 3s 852ms/step - loss: 0.0463
# Epoch 47/100
# 4/4 [==============================] - 4s 878ms/step - loss: 0.0488
# Epoch 48/100
# 4/4 [==============================] - 4s 965ms/step - loss: 0.0463
# Epoch 49/100
# 4/4 [==============================] - 4s 882ms/step - loss: 0.0485
# Epoch 50/100
# 4/4 [==============================] - 4s 927ms/step - loss: 0.0615
# Epoch 51/100
# 4/4 [==============================] - 4s 889ms/step - loss: 0.0530
# Epoch 52/100
# 4/4 [==============================] - 4s 1s/step - loss: 0.0580
# Epoch 53/100
# 4/4 [==============================] - 4s 926ms/step - loss: 0.0610
# Epoch 54/100
# 4/4 [==============================] - 4s 929ms/step - loss: 0.0584
# Epoch 55/100
# 4/4 [==============================] - 4s 969ms/step - loss: 0.0518
# Epoch 56/100
# 4/4 [==============================] - 4s 887ms/step - loss: 0.0560
# Epoch 57/100
# 4/4 [==============================] - 4s 957ms/step - loss: 0.0528
# Epoch 58/100
# 4/4 [==============================] - 4s 910ms/step - loss: 0.0444
# Epoch 59/100
# 4/4 [==============================] - 4s 927ms/step - loss: 0.0440
# Epoch 60/100
# 4/4 [==============================] - 4s 909ms/step - loss: 0.0385
# Epoch 61/100
# 4/4 [==============================] - 4s 919ms/step - loss: 0.0399
# Epoch 62/100
# 4/4 [==============================] - 4s 893ms/step - loss: 0.0367
# Epoch 63/100
# 4/4 [==============================] - 4s 954ms/step - loss: 0.0346
# Epoch 64/100
# 4/4 [==============================] - 4s 897ms/step - loss: 0.0316
# Epoch 65/100
# 4/4 [==============================] - 4s 857ms/step - loss: 0.0298
# Epoch 66/100
# 4/4 [==============================] - 4s 926ms/step - loss: 0.0304
# Epoch 67/100
# 4/4 [==============================] - 4s 923ms/step - loss: 0.0304
# Epoch 68/100
# 4/4 [==============================] - 4s 871ms/step - loss: 0.0309
# Epoch 69/100
# 4/4 [==============================] - 4s 953ms/step - loss: 0.0281
# Epoch 70/100
# 4/4 [==============================] - 4s 906ms/step - loss: 0.0321
# Epoch 71/100
# 4/4 [==============================] - 4s 905ms/step - loss: 0.0291
# Epoch 72/100
# 4/4 [==============================] - 4s 893ms/step - loss: 0.0284
# Epoch 73/100
# 4/4 [==============================] - 4s 896ms/step - loss: 0.0274
# Epoch 74/100
# 4/4 [==============================] - 4s 947ms/step - loss: 0.0272
# Epoch 75/100
# 4/4 [==============================] - 4s 895ms/step - loss: 0.0268
# Epoch 76/100
# 4/4 [==============================] - 4s 852ms/step - loss: 0.0275
# Epoch 77/100
# 4/4 [==============================] - 4s 925ms/step - loss: 0.0277
# Epoch 78/100
# 4/4 [==============================] - 3s 837ms/step - loss: 0.0247
# Epoch 79/100
# 4/4 [==============================] - 4s 887ms/step - loss: 0.0254
# Epoch 80/100
# 4/4 [==============================] - 4s 851ms/step - loss: 0.0251
# Epoch 81/100
# 4/4 [==============================] - 4s 903ms/step - loss: 0.0251
# Epoch 82/100
# 4/4 [==============================] - 4s 893ms/step - loss: 0.0274
# Epoch 83/100
# 4/4 [==============================] - 4s 851ms/step - loss: 0.0217
# Epoch 84/100
# 4/4 [==============================] - 4s 922ms/step - loss: 0.0223
# Epoch 85/100
# 4/4 [==============================] - 4s 913ms/step - loss: 0.0204
# Epoch 86/100
# 4/4 [==============================] - 4s 917ms/step - loss: 0.0197
# Epoch 87/100
# 4/4 [==============================] - 4s 968ms/step - loss: 0.0200
# Epoch 88/100
# 4/4 [==============================] - 4s 871ms/step - loss: 0.0184
# Epoch 89/100
# 4/4 [==============================] - 4s 940ms/step - loss: 0.0174
# Epoch 90/100
# 4/4 [==============================] - 4s 879ms/step - loss: 0.0218
# Epoch 91/100
# 4/4 [==============================] - 4s 913ms/step - loss: 0.0188
# Epoch 92/100
# 4/4 [==============================] - 4s 898ms/step - loss: 0.0199
# Epoch 93/100
# 4/4 [==============================] - 4s 876ms/step - loss: 0.0237
# Epoch 94/100
# 4/4 [==============================] - 4s 876ms/step - loss: 0.0171
# Epoch 95/100
# 4/4 [==============================] - 4s 871ms/step - loss: 0.0214
# Epoch 96/100
# 4/4 [==============================] - 4s 964ms/step - loss: 0.0181
# Epoch 97/100
# 4/4 [==============================] - 4s 871ms/step - loss: 0.0168
# Epoch 98/100
# 4/4 [==============================] - 4s 858ms/step - loss: 0.0173
# Epoch 99/100
# 4/4 [==============================] - 4s 892ms/step - loss: 0.0150
# Epoch 100/100
# 4/4 [==============================] - 4s 873ms/step - loss: 0.0170

# %%
y_predict = np.zeros((51, 89351))
y_predict[0,:] = X[102,:]
for j in range(50):
    y_predict[j+1,:] = model.predict(np.reshape(y_predict[j,:],(1,89351)))
y_predict = y_predict.T

# %%
n_vortall = np.shape(y_predict)[1]

pred = np.reshape(y_predict, (449, 199, n_vortall))

test_path = '/Users/zhhh/databook_python/CH06/fig_test/'
for i in range(np.shape(pred)[2]):
    skimage.io.imsave(test_path + str(i) + '.png', pred[:,:,i])

# %%
import imageio
#plot flow
def plotFlow(X):    
    ## Plot Mode 2
    vortmin = -5
    vortmax = 5
    V2 = np.copy(np.real(np.reshape(X,(449,199))))
    V2 = V2.T

    # normalize values... not symmetric
    minval = np.min(V2)
    maxval = np.max(V2)

    if np.abs(minval) < 5 and np.abs(maxval) < 5:
        if np.abs(minval) > np.abs(maxval):
            vortmax = maxval
            vortmin = -maxval
        else:
            vortmin = minval
            vortmax = -minval

    V2[V2 > vortmax] = vortmax
    V2[V2 < vortmin] = vortmin

    plt.imshow(V2,cmap='jet',vmin=vortmin,vmax=vortmax)

    cvals = np.array([-4,-2,-1,-0.5,-0.25,-0.155])
    plt.contour(V2,cvals*vortmax/5,colors='k',linestyles='dashed',linewidths=1)
    plt.contour(V2,np.flip(-cvals)*vortmax/5,colors='k',linestyles='solid',linewidths=0.4)

    plt.scatter(49,99,5000,color='k') # draw cylinder

    #plt.show()
#create movie
def createMovie(X):
    plt.rcParams['figure.figsize'] = [8, 8]
    filenames = []
    for i in range(50):
        plotFlow(X[:,i])
        filename = './fig_test/'+str(i)+'.png'
        filenames.append(filename)
        plt.savefig(filename)
        plt.close()
    with imageio.get_writer('vort_pred.gif', mode='I') as writer:
        for filename in filenames:
            image = imageio.v2.imread(filename)
            writer.append_data(image)
    for filename in set(filenames):
        os.remove(filename)

# %%
from IPython.display import Image
createMovie(y_predict)
Image(url='vort_pred.gif')
# Out:
# <img src="vort_pred.gif"/>

# %% [markdown]
# ## LSTM NN

# %%
sequence_size = 10
train_size = 100
test_size = 50
rnn_input = np.zeros((train_size*151-sequence_size-1),sequence_size, 89351)
rnn_output = np.zeros((train_size*151-sequence_size-1),sequence_size, 89351)
for k in range(151-sequence_size-1):
    rnn_input[(151-sequence_size-1) + k, :] =

# %%
model_LSTM = Sequential()
model.add(LSTM(16,input_shape = (None, 89351)))
model.add(Dense(89351))
sgd = optimizers.SGD(0.01)
model.compile(optimizer = sgd, loss = 'mean_square_error')
model.fit(rnn_input, rnn_output, epochs = 20)
